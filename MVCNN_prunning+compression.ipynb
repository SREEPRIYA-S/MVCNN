# %%
# !git clone https://github.com/SREEPRIYA-S/MVCNN.git
# Out:
# Cloning into 'MVCNN'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 20 (delta 5), reused 12 (delta 1), pack-reused 0
# Receiving objects: 100% (20/20), 9.42 KiB | 9.42 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# !pip install tensorboardX
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 3.2 MB/s eta 0:00:00
# ...

# %%
# !wget http://supermoe.cs.umass.edu/shape_recog/shaded_images.tar.gz
# Out:
# --2023-12-19 20:45:14--  http://supermoe.cs.umass.edu/shape_recog/shaded_images.tar.gz
# Resolving supermoe.cs.umass.edu (supermoe.cs.umass.edu)... 128.119.244.95
# Connecting to supermoe.cs.umass.edu (supermoe.cs.umass.edu)|128.119.244.95|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1623290855 (1.5G) [application/x-gzip]
# Saving to: ‘shaded_images.tar.gz’
#
# shaded_images.tar.g 100%[===================>]   1.51G   506KB/s    in 27m 20s
#
# 2023-12-19 21:12:35 (967 KB/s) - ‘shaded_images.tar.gz’ saved [1623290855/1623290855]

# %%
# !tar -xvzf shaded_images.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# modelnet40_images_new_12x/curtain/train/curtain_0050.obj.shaded_v004.png
# modelnet40_images_new_12x/curtain/train/curtain_0122.obj.shaded_v007.png
# modelnet40_images_new_12x/curtain/train/curtain_0106.obj.shaded_v010.png
# modelnet40_images_new_12x/curtain/train/curtain_0072.obj.shaded_v006.png
# modelnet40_images_new_12x/curtain/train/curtain_0136.obj.shaded_v001.png
# modelnet40_images_new_12x/curtain/train/curtain_0103.obj.shaded_v011.png
# modelnet40_images_new_12x/curtain/train/curtain_0128.obj.shaded_v008.png
# modelnet40_images_new_12x/curtain/train/curtain_0123.obj.shaded_v004.png
# modelnet40_images_new_12x/curtain/train/curtain_0052.obj.shaded_v007.png
# modelnet40_images_new_12x/curtain/train/curtain_0001.obj.shaded_v006.png
# modelnet40_images_new_12x/curtain/train/curtain_0129.obj.shaded_v001.png
# modelnet40_images_new_12x/curtain/train/curtain_0003.obj.shaded_v007.png
# ...

# %%
# !pip install nni==2.9
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 MB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.2/115.2 kB 17.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 18.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 53.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 21.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 38.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: hyperopt
#     Found existing installation: hyperopt 0.2.7
#     Uninstalling hyperopt-0.2.7:
#       Successfully uninstalled hyperopt-0.2.7
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !python MVCNN/train_mvcnn.py -name mvcnn -num_models 1 -weight_decay 0.001 -num_views 12 -cnn_name vgg11
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG11_Weights.IMAGENET1K_V1`. You can also use `weights=VGG11_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg11-8a719046.pth" to /root/.cache/torch/hub/checkpoints/vgg11-8a719046.pth
# 100% 507M/507M [00:13<00:00, 38.9MB/s]
# num_train_files: 480
# num_val_files: 29616
# **********************************************************************************************
# -----------Testing Accuracy----------------
# ...
